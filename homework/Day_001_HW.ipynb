# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    return sum((y - yp)**2)/len(y)

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 232.590
# The Mean absolute error is 12.235

# %% [markdown]
# # [作業2]
#
# ### 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#    Data:
#    [Greenhouse gas emissions in the Netherlands](https://www.kaggle.com/janheindejong/greenhouse-gas-emissions-in-the-netherlands)
#
# ### 1. 你選的這組資料為何重要
#     近年來全球氣溫快速上升，主要就是由於人為作用，使大氣中溫室氣體的濃度極劇上升所導致的。
#     故分析溫室氣體的主要來源，可幫助我們思考如何去降低溫室氣體的產生及改善。
# ### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     資料是根據IPCC指南/方法，從荷蘭中央統計局(Dutch Central Bureau of Statistics, CBS）網站下載的溫室氣體排放數據。
# ### 3. 蒐集而來的資料型態為何
#     結構化資料: csv
#     半結構化資料: json
# ### 4. 這組資料想解決的問題如何評估
#     了解溫室氣體主要的來源，以及隨著時間的推移溫室氣體的變化。
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# ### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     如何提升載客量，不同時間及不同地點的載客效率。
# ### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     過去歷史的載客資料，若是有手機app叫車，則能從app數據庫分析消費者叫車的習慣。
# ### 3. 蒐集而來的資料型態為何
#     結構化資料: 數值、類別資料
#     可能為csv或json檔。
# ### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     藉由叫車app分析消費者的叫車習慣，區分出各個時段的熱門叫車地點，並根據各個地點的平均載客率，分配相對應的司機數量在該區。
